# %% [markdown]
# # Installing Database

# %%
#         ----> SQL ---->
#  Python                  Database System
#       -----< Data <-----

# %%
# App Client           
#                            API Layer
# Database                    Server
#                         Storage Engine
# 
#
# Memory   Flash/SSD   Flash Disks   Capacity Disks   Cloud Storage
#   &        Tier 1      Tier 2        Tier 3          Tier N
# Storage

# %% [markdown]
# ## Database

# %% [markdown]
# The python standard for database interfaces is the python DB-API. Most python database interfaces adhere to this standard.
# You can choose any database for your application.
# GadFly, mSQL, MySQL, PostgreSQL, Microsoft SQL Server 2000, Informix, Interbase, Oracle, Sybase

# %% [markdown]
# ### Database Installation Step

# %% [markdown]
# First install pymysql library using following command in cmd.
# Pip install pymysql
# Install SQLOG software for database work.

# %% [markdown]
# ### Step for working with database

# %% [markdown]
# Importing the API module.
# Acquiring a connection with the database.
# issuing sql statements.
# Closing the connection.

# %% [markdown]
# ### Step for working with database

# %% [markdown]
# Importing the API module.
#    Import pymysql
# Acquiring a connection with the Database.
# Conn =  pymysql.connect(
# Host = "",  (Local)
# Database = "",    (Database name)
# User = "",      (by default = root)
# Password = "",   ( your password)
# Port = 3306)

# %% [markdown]
# ### Import pymysql API

# %%
import pymysql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pymysql
#
# ModuleNotFoundError: No module named 'pymysql'

# %% [markdown]
# ### Creating Connection with Database

# %%
def Createconn():
    return pymysql.connect(host="localhost",database="learnvern",user="root",password="190694",port=3306)

# %% [markdown]
# ### Step for working with database

# %% [markdown]
# Issuing SQL statement.
# cursor = conn.cursor()  # cursor is used for execute query
# query = ""
# cursor.execute(query) # execute is used to execute query or fire a query

# %% [markdown]
# Closing the connection
# conn.commit() # commit is use for save
# conn.close() # close method for close the connection

# %% [markdown]
# # According to my class offline class

# %%
# install mysql connection package
# !pip install mysql-connector-python
# Out:
# ...
#   Obtaining dependency information for mysql-connector-python from https://files.pythonhosted.org/packages/d9/91/007a0d60fee8db4f7385075dc50bf62d2d359b417b374ec06b06ce6c2d64/mysql_connector_python-8.3.0-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.4 MB 660.6 kB/s eta 0:00:24
#    ---------------------------------------- 0.1/15.4 MB 656.4 kB/s eta 0:00:24
#    ---------------------------------------- 0.1/15.4 MB 459.5 kB/s eta 0:00:34
#    ---------------------------------------- 0.1/15.4 MB 438.1 kB/s eta 0:00:35
#    ---------------------------------------- 0.1/15.4 MB 438.1 kB/s eta 0:00:35
#    ---------------------------------------- 0.1/15.4 MB 438.1 kB/s eta 0:00:35
#    ---------------------------------------- 0.1/15.4 MB 438.1 kB/s eta 0:00:35
# ...

# %%
# import module
import mysql.connector as conn

# %%
# make a connection with mysql
mydb = conn.connect(host="localhost", user="root", password="190694")

print(mydb)

# %%
#create a database in mysql 
mycursor = mydb.cursor()

# %%
mycursor.execute("CREATE DATABASE df")

# %%
print(mycursor)
# Out:
# CMySQLCursor: CREATE DATABASE df

# %%
#show database
mycursor.execute("SHOW DATABASES")
mycursor.fetchall()
#for x in result:
    #print(x)
# Out:
# [('class_11',),
#  ('class_12',),
#  ('df',),
#  ('dress',),
#  ('information_schema',),
#  ('learnvern',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('world',)]

# %%
mycursor.execute("DROP DATABASE df")

# %%
mycursor.execute("SHOW DATABASES")
mycursor.fetchall()
# Out:
# [('class_11',),
#  ('class_12',),
#  ('dress',),
#  ('information_schema',),
#  ('learnvern',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('world',)]

# %%
mycursor.execute("CREATE DATABASE df")

# %%
mycursor.execute("SHOW DATABASES")
mycursor.fetchall()
# Out:
# [('class_11',),
#  ('class_12',),
#  ('df',),
#  ('dress',),
#  ('information_schema',),
#  ('learnvern',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('world',)]

# %%
mycursor.execute("USE df")

# %%
#CREATE TABLE 
mycursor.execute("CREATE TABLE customer (name VARCHAR(255), address VARCHAR(255))")

# %% [markdown]
# ### till create a table by using amit sirs technique
